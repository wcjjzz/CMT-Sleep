# %%
# !pip list

# %%
# !cd /root/autodl-tmp/CMT-Sleep
# !pip3 install -r requirements.txt

# %%
# !pip install torch==1.11.0+cu113 -f https://mirror.sjtu.edu.cn/pytorch-wheels/cu113/?mirror_intel_list

# %%
# !python /root/autodl-tmp/CMT-Sleep/data_preparations/new_single_epoch.py
# Out:
# 蔡创荣20191111.edf matched 蔡创荣20191111_mne_Annotation.txt
# 曾燕清20190730.edf matched 曾燕清20190730_mne_Annotation.txt
# 曾樱20190927.edf matched 曾樱20190927_mne_Annotation.txt
# 陈佳彤20190514.edf matched 陈佳彤20190514_mne_Annotation.txt
# 陈甜珍20190829.edf matched 陈甜珍20190829_mne_Annotation.txt
# 仇伟利20181015.edf matched 仇伟利20181015_mne_Annotation.txt
# 方彩霞20190521.edf matched 方彩霞20190521_mne_Annotation.txt
# 胡锐20190918.edf matched 胡锐20190918_mne_Annotation.txt
# 黄柏能20181130.edf matched 黄柏能20181130_mne_Annotation.txt
# 黄省英20190320.edf matched 黄省英20190320_mne_Annotation.txt
# 黄钻20190531.edf matched 黄钻20190531_mne_Annotation.txt
# 黎锦群20190715.edf matched 黎锦群20190715_mne_Annotation.txt
# 李静容20190408.edf matched 李静容20190408_mne_Annotation.txt
# 李如花20190823.edf matched 李如花20190823_mne_Annotation.txt
# 李瑞芳20180126.edf matched 李瑞芳20180126_mne_Annotation.txt
# 李秀云20181205.edf matched 李秀云20181205_mne_Annotation.txt
# 李余20181126.edf matched 李余20181126_mne_Annotation.txt
# ...
